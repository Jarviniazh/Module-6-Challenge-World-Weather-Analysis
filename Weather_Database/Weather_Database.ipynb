# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.00, high=180.000, size =2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
    
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
import time

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | talnakh
# Processing Record 2 of Set 1 | deder
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | faya
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | chapais
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | saint-augustin
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | verkh-usugli
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | presidencia roque saenz pena
# Processing Record 15 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 1 | east london
# Processing Record 17 of Set 1 | staryy nadym
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | nicoya
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | bujaru
# Processing Record 24 of Set 1 | steinbach
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | airai
# Processing Record 27 of Set 1 | nishihara
# Processing Record 28 of Set 1 | klaksvik
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | cedral
# Processing Record 32 of Set 1 | kruisfontein
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | aitape
# Processing Record 35 of Set 1 | putina
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | nantucket
# Processing Record 39 of Set 1 | nizhniy kuranakh
# Processing Record 40 of Set 1 | tuatapere
# Processing Record 41 of Set 1 | jumla
# Processing Record 42 of Set 1 | pavlohrad
# Processing Record 43 of Set 1 | oranjemund
# Processing Record 44 of Set 1 | umea
# Processing Record 45 of Set 1 | sitka
# Processing Record 46 of Set 1 | sinnamary
# Processing Record 47 of Set 1 | naugachhia
# Processing Record 48 of Set 1 | asau
# Processing Record 49 of Set 1 | lebu
# Processing Record 50 of Set 1 | waitati
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | agadir
# Processing Record 6 of Set 2 | isangel
# Processing Record 7 of Set 2 | taoudenni
# Processing Record 8 of Set 2 | rawson
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | jahrom
# City not found. Skipping...
# Processing Record 11 of Set 2 | pokosnoye
# Processing Record 12 of Set 2 | olpad
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | hobyo
# Processing Record 18 of Set 2 | thinadhoo
# Processing Record 19 of Set 2 | pandan
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | bagdarin
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | diamantino
# Processing Record 24 of Set 2 | fatezh
# Processing Record 25 of Set 2 | touros
# Processing Record 26 of Set 2 | moussoro
# Processing Record 27 of Set 2 | korla
# Processing Record 28 of Set 2 | luwuk
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | busselton
# Processing Record 31 of Set 2 | guerrero negro
# Processing Record 32 of Set 2 | urucara
# Processing Record 33 of Set 2 | iqaluit
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | tasiilaq
# Processing Record 36 of Set 2 | colac
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | bacong
# Processing Record 39 of Set 2 | omboue
# Processing Record 40 of Set 2 | strezhevoy
# Processing Record 41 of Set 2 | katsuura
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | makat
# Processing Record 44 of Set 2 | castro
# Processing Record 45 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 2 | xining
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | cape town
# Processing Record 49 of Set 2 | segovia
# Processing Record 50 of Set 2 | zhezkazgan
# Processing Record 1 of Set 3 | almaznyy
# Processing Record 2 of Set 3 | jimma
# Processing Record 3 of Set 3 | westport
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | port augusta
# Processing Record 6 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | nemuro
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | ulladulla
# Processing Record 11 of Set 3 | ladario
# Processing Record 12 of Set 3 | praia
# Processing Record 13 of Set 3 | bosanska kostajnica
# Processing Record 14 of Set 3 | sheridan
# Processing Record 15 of Set 3 | praia da vitoria
# Processing Record 16 of Set 3 | saint combs
# City not found. Skipping...
# Processing Record 17 of Set 3 | pangnirtung
# Processing Record 18 of Set 3 | sobolevo
# Processing Record 19 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 3 | callaway
# Processing Record 21 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 22 of Set 3 | aklavik
# Processing Record 23 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 3 | polunochnoye
# Processing Record 25 of Set 3 | christchurch
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | idaho falls
# Processing Record 29 of Set 3 | khandyga
# Processing Record 30 of Set 3 | bon accord
# Processing Record 31 of Set 3 | hofn
# Processing Record 32 of Set 3 | haimen
# Processing Record 33 of Set 3 | tura
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | san luis
# Processing Record 37 of Set 3 | saskylakh
# Processing Record 38 of Set 3 | kampot
# Processing Record 39 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 3 | sur
# Processing Record 41 of Set 3 | mount gambier
# Processing Record 42 of Set 3 | pascagoula
# Processing Record 43 of Set 3 | kudahuvadhoo
# Processing Record 44 of Set 3 | harper
# Processing Record 45 of Set 3 | mahebourg
# Processing Record 46 of Set 3 | hermanus
# Processing Record 47 of Set 3 | karratha
# Processing Record 48 of Set 3 | naze
# Processing Record 49 of Set 3 | cabo san lucas
# Processing Record 50 of Set 3 | thunder bay
# Processing Record 1 of Set 4 | lolodorf
# Processing Record 2 of Set 4 | saurimo
# Processing Record 3 of Set 4 | samana
# Processing Record 4 of Set 4 | matara
# Processing Record 5 of Set 4 | ojinaga
# Processing Record 6 of Set 4 | arraial do cabo
# Processing Record 7 of Set 4 | fayaoue
# Processing Record 8 of Set 4 | kamloops
# Processing Record 9 of Set 4 | miraflores
# Processing Record 10 of Set 4 | okha
# Processing Record 11 of Set 4 | awjilah
# Processing Record 12 of Set 4 | acapulco
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | bredasdorp
# Processing Record 15 of Set 4 | nuuk
# Processing Record 16 of Set 4 | pauini
# Processing Record 17 of Set 4 | kodiak
# Processing Record 18 of Set 4 | velsk
# Processing Record 19 of Set 4 | arman
# Processing Record 20 of Set 4 | vila velha
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | bonthe
# Processing Record 23 of Set 4 | juneau
# Processing Record 24 of Set 4 | meulaboh
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | kingman
# Processing Record 27 of Set 4 | severo-yeniseyskiy
# Processing Record 28 of Set 4 | syumsi
# Processing Record 29 of Set 4 | tevaitoa
# Processing Record 30 of Set 4 | malappuram
# Processing Record 31 of Set 4 | pietermaritzburg
# Processing Record 32 of Set 4 | miri
# Processing Record 33 of Set 4 | aripuana
# Processing Record 34 of Set 4 | cascais
# Processing Record 35 of Set 4 | itapipoca
# Processing Record 36 of Set 4 | yashkul
# Processing Record 37 of Set 4 | victoria
# Processing Record 38 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 4 | tarakan
# Processing Record 40 of Set 4 | olafsvik
# Processing Record 41 of Set 4 | mendeleyevo
# Processing Record 42 of Set 4 | emba
# Processing Record 43 of Set 4 | nakur
# Processing Record 44 of Set 4 | qaanaaq
# Processing Record 45 of Set 4 | bluff
# Processing Record 46 of Set 4 | teodoro sampaio
# Processing Record 47 of Set 4 | ballina
# Processing Record 48 of Set 4 | faanui
# Processing Record 49 of Set 4 | sidi ali
# Processing Record 50 of Set 4 | talcahuano
# Processing Record 1 of Set 5 | geraldton
# Processing Record 2 of Set 5 | nichinan
# Processing Record 3 of Set 5 | shelburne
# Processing Record 4 of Set 5 | fortuna
# Processing Record 5 of Set 5 | amuntai
# Processing Record 6 of Set 5 | manuk mangkaw
# Processing Record 7 of Set 5 | barrow
# Processing Record 8 of Set 5 | daska
# Processing Record 9 of Set 5 | mataura
# Processing Record 10 of Set 5 | kavieng
# Processing Record 11 of Set 5 | dingle
# Processing Record 12 of Set 5 | springbok
# Processing Record 13 of Set 5 | katsikas
# Processing Record 14 of Set 5 | vaitape
# Processing Record 15 of Set 5 | mar del plata
# Processing Record 16 of Set 5 | longyearbyen
# Processing Record 17 of Set 5 | new norfolk
# Processing Record 18 of Set 5 | ilulissat
# Processing Record 19 of Set 5 | lasa
# Processing Record 20 of Set 5 | saldanha
# Processing Record 21 of Set 5 | salinas
# Processing Record 22 of Set 5 | las vegas
# Processing Record 23 of Set 5 | barguzin
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | dzhebariki-khaya
# Processing Record 26 of Set 5 | luba
# Processing Record 27 of Set 5 | demyanovo
# Processing Record 28 of Set 5 | ugoofaaru
# Processing Record 29 of Set 5 | mariental
# Processing Record 30 of Set 5 | prestonpans
# Processing Record 31 of Set 5 | constitucion
# Processing Record 32 of Set 5 | san quintin
# Processing Record 33 of Set 5 | esperance
# Processing Record 34 of Set 5 | paris
# Processing Record 35 of Set 5 | salalah
# Processing Record 36 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 5 | souillac
# Processing Record 38 of Set 5 | ginda
# Processing Record 39 of Set 5 | play cu
# City not found. Skipping...
# Processing Record 40 of Set 5 | zeya
# Processing Record 41 of Set 5 | charters towers
# Processing Record 42 of Set 5 | vardo
# Processing Record 43 of Set 5 | taltal
# Processing Record 44 of Set 5 | sydney
# Processing Record 45 of Set 5 | pankrushikha
# Processing Record 46 of Set 5 | campestre
# Processing Record 47 of Set 5 | tambura
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | umm lajj
# Processing Record 50 of Set 5 | brejo santo
# Processing Record 1 of Set 6 | tilichiki
# Processing Record 2 of Set 6 | hasaki
# Processing Record 3 of Set 6 | te anau
# Processing Record 4 of Set 6 | shimoda
# Processing Record 5 of Set 6 | svetlogorsk
# Processing Record 6 of Set 6 | kurilsk
# Processing Record 7 of Set 6 | niquelandia
# Processing Record 8 of Set 6 | takoradi
# Processing Record 9 of Set 6 | grand gaube
# Processing Record 10 of Set 6 | the valley
# Processing Record 11 of Set 6 | itoman
# Processing Record 12 of Set 6 | georgetown
# Processing Record 13 of Set 6 | coquimbo
# Processing Record 14 of Set 6 | kisanga
# Processing Record 15 of Set 6 | sao filipe
# Processing Record 16 of Set 6 | guanica
# Processing Record 17 of Set 6 | nouadhibou
# Processing Record 18 of Set 6 | richards bay
# Processing Record 19 of Set 6 | atlantic beach
# Processing Record 20 of Set 6 | upington
# Processing Record 21 of Set 6 | rock sound
# Processing Record 22 of Set 6 | yingshang
# City not found. Skipping...
# Processing Record 23 of Set 6 | goundam
# Processing Record 24 of Set 6 | ostrovnoy
# Processing Record 25 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 26 of Set 6 | aguimes
# Processing Record 27 of Set 6 | leningradskiy
# Processing Record 28 of Set 6 | bedele
# Processing Record 29 of Set 6 | agropoli
# Processing Record 30 of Set 6 | qaqortoq
# Processing Record 31 of Set 6 | walvis bay
# Processing Record 32 of Set 6 | hubli
# Processing Record 33 of Set 6 | spornoye
# Processing Record 34 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 6 | ayan
# Processing Record 36 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 6 | beringovskiy
# Processing Record 38 of Set 6 | inirida
# Processing Record 39 of Set 6 | concepcion del uruguay
# Processing Record 40 of Set 6 | rio gallegos
# Processing Record 41 of Set 6 | ali-berdukovskiy
# Processing Record 42 of Set 6 | veraval
# Processing Record 43 of Set 6 | ende
# Processing Record 44 of Set 6 | port hedland
# Processing Record 45 of Set 6 | yeniseysk
# Processing Record 46 of Set 6 | sioux lookout
# Processing Record 47 of Set 6 | peleduy
# Processing Record 48 of Set 6 | namatanai
# Processing Record 49 of Set 6 | cozumel
# Processing Record 50 of Set 6 | lincoln
# Processing Record 1 of Set 7 | boende
# Processing Record 2 of Set 7 | khash
# Processing Record 3 of Set 7 | voh
# Processing Record 4 of Set 7 | pataias
# Processing Record 5 of Set 7 | kulhudhuffushi
# Processing Record 6 of Set 7 | norman wells
# Processing Record 7 of Set 7 | bathsheba
# Processing Record 8 of Set 7 | bolgar
# Processing Record 9 of Set 7 | berlevag
# Processing Record 10 of Set 7 | qui nhon
# Processing Record 11 of Set 7 | pevek
# Processing Record 12 of Set 7 | birin
# Processing Record 13 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 7 | bilibino
# Processing Record 15 of Set 7 | nagapattinam
# Processing Record 16 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 7 | muzhi
# Processing Record 18 of Set 7 | sola
# Processing Record 19 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 7 | burica
# City not found. Skipping...
# Processing Record 21 of Set 7 | mudanjiang
# Processing Record 22 of Set 7 | san pedro de macoris
# Processing Record 23 of Set 7 | porosozero
# Processing Record 24 of Set 7 | najran
# Processing Record 25 of Set 7 | lenine
# Processing Record 26 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 7 | outjo
# Processing Record 28 of Set 7 | vera cruz
# Processing Record 29 of Set 7 | vila
# Processing Record 30 of Set 7 | san cristobal
# Processing Record 31 of Set 7 | ancud
# Processing Record 32 of Set 7 | mnogovershinnyy
# Processing Record 33 of Set 7 | avera
# Processing Record 34 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 35 of Set 7 | narsaq
# Processing Record 36 of Set 7 | sile
# Processing Record 37 of Set 7 | ust-nera
# Processing Record 38 of Set 7 | sambava
# Processing Record 39 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 7 | verkhovazhye
# Processing Record 42 of Set 7 | roma
# Processing Record 43 of Set 7 | hambantota
# Processing Record 44 of Set 7 | cherskiy
# Processing Record 45 of Set 7 | alice springs
# Processing Record 46 of Set 7 | santa cruz
# Processing Record 47 of Set 7 | inhambane
# Processing Record 48 of Set 7 | champerico
# Processing Record 49 of Set 7 | salinopolis
# Processing Record 50 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 8 | pringsewu
# Processing Record 2 of Set 8 | gander
# Processing Record 3 of Set 8 | tessalit
# Processing Record 4 of Set 8 | laje
# Processing Record 5 of Set 8 | sao domingos do prata
# Processing Record 6 of Set 8 | chumikan
# Processing Record 7 of Set 8 | goderich
# Processing Record 8 of Set 8 | barreirinha
# Processing Record 9 of Set 8 | bintulu
# Processing Record 10 of Set 8 | san ignacio
# Processing Record 11 of Set 8 | puteyets
# Processing Record 12 of Set 8 | tabou
# Processing Record 13 of Set 8 | cam ranh
# Processing Record 14 of Set 8 | kedrovyy
# Processing Record 15 of Set 8 | bubaque
# Processing Record 16 of Set 8 | suhut
# Processing Record 17 of Set 8 | princeton
# Processing Record 18 of Set 8 | aksarka
# Processing Record 19 of Set 8 | iwanai
# Processing Record 20 of Set 8 | lokachi
# Processing Record 21 of Set 8 | nador
# Processing Record 22 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 23 of Set 8 | nattam
# Processing Record 24 of Set 8 | atambua
# Processing Record 25 of Set 8 | fez
# Processing Record 26 of Set 8 | norcasia
# Processing Record 27 of Set 8 | hokitika
# Processing Record 28 of Set 8 | cabedelo
# Processing Record 29 of Set 8 | kodinsk
# Processing Record 30 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 31 of Set 8 | budelsdorf
# Processing Record 32 of Set 8 | ixtapa
# Processing Record 33 of Set 8 | lavrentiya
# Processing Record 34 of Set 8 | douentza
# Processing Record 35 of Set 8 | cidreira
# Processing Record 36 of Set 8 | ekhabi
# Processing Record 37 of Set 8 | okhotsk
# Processing Record 38 of Set 8 | miltenberg
# Processing Record 39 of Set 8 | hami
# Processing Record 40 of Set 8 | abu samrah
# Processing Record 41 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 8 | fontem
# Processing Record 43 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 44 of Set 8 | codrington
# Processing Record 45 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 8 | batemans bay
# Processing Record 47 of Set 8 | gat
# Processing Record 48 of Set 8 | burnie
# Processing Record 49 of Set 8 | mirnyy
# Processing Record 50 of Set 8 | reinosa
# Processing Record 1 of Set 9 | sao joao da barra
# Processing Record 2 of Set 9 | zhongshu
# Processing Record 3 of Set 9 | saint george
# Processing Record 4 of Set 9 | lima
# Processing Record 5 of Set 9 | surt
# Processing Record 6 of Set 9 | mielec
# Processing Record 7 of Set 9 | murmansk
# Processing Record 8 of Set 9 | mayumba
# Processing Record 9 of Set 9 | bluefield
# Processing Record 10 of Set 9 | mubi
# Processing Record 11 of Set 9 | verkhnevilyuysk
# Processing Record 12 of Set 9 | paso de carrasco
# Processing Record 13 of Set 9 | vanimo
# Processing Record 14 of Set 9 | puri
# Processing Record 15 of Set 9 | naryan-mar
# Processing Record 16 of Set 9 | kaitangata
# Processing Record 17 of Set 9 | tupelo
# Processing Record 18 of Set 9 | nalut
# Processing Record 19 of Set 9 | sanbu
# Processing Record 20 of Set 9 | velizh
# Processing Record 21 of Set 9 | vaijapur
# Processing Record 22 of Set 9 | gheorgheni
# Processing Record 23 of Set 9 | uriangato
# Processing Record 24 of Set 9 | puerto escondido
# Processing Record 25 of Set 9 | balabac
# Processing Record 26 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 9 | banes
# Processing Record 28 of Set 9 | wajir
# Processing Record 29 of Set 9 | ust-kuyga
# Processing Record 30 of Set 9 | hailar
# Processing Record 31 of Set 9 | clarence town
# Processing Record 32 of Set 9 | tommot
# Processing Record 33 of Set 9 | ayabaca
# Processing Record 34 of Set 9 | den helder
# Processing Record 35 of Set 9 | wagar
# Processing Record 36 of Set 9 | lewiston
# Processing Record 37 of Set 9 | karasburg
# Processing Record 38 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 39 of Set 9 | kavaratti
# Processing Record 40 of Set 9 | kaili
# Processing Record 41 of Set 9 | pisco
# Processing Record 42 of Set 9 | igarka
# Processing Record 43 of Set 9 | marrakesh
# Processing Record 44 of Set 9 | tazovskiy
# Processing Record 45 of Set 9 | saquena
# Processing Record 46 of Set 9 | ngunguru
# Processing Record 47 of Set 9 | pecos
# Processing Record 48 of Set 9 | zhigansk
# Processing Record 49 of Set 9 | kjollefjord
# Processing Record 50 of Set 9 | hamilton
# Processing Record 1 of Set 10 | barranca
# Processing Record 2 of Set 10 | viedma
# Processing Record 3 of Set 10 | krasnoselkup
# Processing Record 4 of Set 10 | ferme-neuve
# Processing Record 5 of Set 10 | cortez
# Processing Record 6 of Set 10 | komsomolskiy
# Processing Record 7 of Set 10 | evensk
# Processing Record 8 of Set 10 | hualmay
# Processing Record 9 of Set 10 | dongying
# Processing Record 10 of Set 10 | tiebissou
# Processing Record 11 of Set 10 | kismayo
# Processing Record 12 of Set 10 | kang
# Processing Record 13 of Set 10 | shambu
# Processing Record 14 of Set 10 | port macquarie
# Processing Record 15 of Set 10 | tambacounda
# Processing Record 16 of Set 10 | nhulunbuy
# Processing Record 17 of Set 10 | chicama
# Processing Record 18 of Set 10 | truth or consequences
# Processing Record 19 of Set 10 | isabela
# Processing Record 20 of Set 10 | port lincoln
# Processing Record 21 of Set 10 | paamiut
# Processing Record 22 of Set 10 | anadyr
# Processing Record 23 of Set 10 | cherusti
# Processing Record 24 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 10 | codo
# Processing Record 26 of Set 10 | kuybyshevskiy zaton
# Processing Record 27 of Set 10 | oneida
# Processing Record 28 of Set 10 | vostok
# Processing Record 29 of Set 10 | batagay
# Processing Record 30 of Set 10 | mecca
# Processing Record 31 of Set 10 | necochea
# Processing Record 32 of Set 10 | cap malheureux
# Processing Record 33 of Set 10 | lieksa
# Processing Record 34 of Set 10 | ucluelet
# Processing Record 35 of Set 10 | lagoa
# Processing Record 36 of Set 10 | itarema
# Processing Record 37 of Set 10 | butembo
# Processing Record 38 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 10 | amahai
# Processing Record 40 of Set 10 | tawang
# Processing Record 41 of Set 10 | raudeberg
# Processing Record 42 of Set 10 | ahuimanu
# Processing Record 43 of Set 10 | ambulu
# Processing Record 44 of Set 10 | kenai
# Processing Record 45 of Set 10 | ambagarh chauki
# Processing Record 46 of Set 10 | aksay
# Processing Record 47 of Set 10 | high level
# Processing Record 48 of Set 10 | kaura namoda
# Processing Record 49 of Set 10 | karpogory
# Processing Record 50 of Set 10 | port hardy
# Processing Record 1 of Set 11 | kajaani
# Processing Record 2 of Set 11 | oistins
# Processing Record 3 of Set 11 | notre-dame-du-lac
# Processing Record 4 of Set 11 | bom jesus
# Processing Record 5 of Set 11 | vyritsa
# Processing Record 6 of Set 11 | yacuiba
# Processing Record 7 of Set 11 | constantine
# Processing Record 8 of Set 11 | santa maria
# Processing Record 9 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 11 | kutulik
# Processing Record 11 of Set 11 | tiblawan
# Processing Record 12 of Set 11 | urumqi
# Processing Record 13 of Set 11 | prnjavor
# Processing Record 14 of Set 11 | vasai
# Processing Record 15 of Set 11 | prince rupert
# Processing Record 16 of Set 11 | jutai
# Processing Record 17 of Set 11 | half moon bay
# Processing Record 18 of Set 11 | palmira
# Processing Record 19 of Set 11 | riyadh
# Processing Record 20 of Set 11 | kuloy
# Processing Record 21 of Set 11 | samarai
# Processing Record 22 of Set 11 | nara
# Processing Record 23 of Set 11 | kilindoni
# Processing Record 24 of Set 11 | broome
# Processing Record 25 of Set 11 | gizo
# Processing Record 26 of Set 11 | san carlos de bariloche
# Processing Record 27 of Set 11 | jand
# Processing Record 28 of Set 11 | parma
# Processing Record 29 of Set 11 | freeport
# Processing Record 30 of Set 11 | yinchuan
# Processing Record 31 of Set 11 | iracoubo
# Processing Record 32 of Set 11 | yusva
# City not found. Skipping...
# Processing Record 33 of Set 11 | ahipara
# Processing Record 34 of Set 11 | comodoro rivadavia
# Processing Record 35 of Set 11 | opportunity
# Processing Record 36 of Set 11 | manyana
# Processing Record 37 of Set 11 | barry
# Processing Record 38 of Set 11 | broken hill
# Processing Record 39 of Set 11 | auki
# Processing Record 40 of Set 11 | borba
# Processing Record 41 of Set 11 | nikolayevka
# Processing Record 42 of Set 11 | katherine
# Processing Record 43 of Set 11 | santa cruz de tenerife
# Processing Record 44 of Set 11 | kamenka
# Processing Record 45 of Set 11 | azar shahr
# City not found. Skipping...
# Processing Record 46 of Set 11 | kapoeta
# Processing Record 47 of Set 11 | college
# Processing Record 48 of Set 11 | cangzhou
# Processing Record 49 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 50 of Set 11 | luanda
# Processing Record 1 of Set 12 | mocuba
# Processing Record 2 of Set 12 | roswell
# Processing Record 3 of Set 12 | warri
# Processing Record 4 of Set 12 | kroderen
# City not found. Skipping...
# Processing Record 5 of Set 12 | locri
# Processing Record 6 of Set 12 | pacific grove
# Processing Record 7 of Set 12 | kemin
# Processing Record 8 of Set 12 | eureka
# Processing Record 9 of Set 12 | vestmanna
# Processing Record 10 of Set 12 | doha
# Processing Record 11 of Set 12 | sept-iles
# Processing Record 12 of Set 12 | mana
# Processing Record 13 of Set 12 | kargapolye
# City not found. Skipping...
# Processing Record 14 of Set 12 | pahrump
# Processing Record 15 of Set 12 | vung tau
# Processing Record 16 of Set 12 | tadine
# Processing Record 17 of Set 12 | boddam
# Processing Record 18 of Set 12 | norsup
# Processing Record 19 of Set 12 | jiuquan
# Processing Record 20 of Set 12 | kaoma
# Processing Record 21 of Set 12 | shestakovo
# Processing Record 22 of Set 12 | la orilla
# Processing Record 23 of Set 12 | semey
# Processing Record 24 of Set 12 | labuhan
# Processing Record 25 of Set 12 | northam
# Processing Record 26 of Set 12 | morgan city
# Processing Record 27 of Set 12 | ketchikan
# Processing Record 28 of Set 12 | chesma
# Processing Record 29 of Set 12 | gladstone
# Processing Record 30 of Set 12 | laguna
# Processing Record 31 of Set 12 | killybegs
# Processing Record 32 of Set 12 | launceston
# Processing Record 33 of Set 12 | kankon
# Processing Record 34 of Set 12 | sokoni
# Processing Record 35 of Set 12 | kyren
# Processing Record 36 of Set 12 | lysyye gory
# Processing Record 37 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 12 | vitimskiy
# City not found. Skipping...
# Processing Record 39 of Set 12 | marzuq
# Processing Record 40 of Set 12 | bandarbeyla
# Processing Record 41 of Set 12 | quatre cocos
# Processing Record 42 of Set 12 | soure
# Processing Record 43 of Set 12 | severnoye
# Processing Record 44 of Set 12 | pangai
# Processing Record 45 of Set 12 | bend
# Processing Record 46 of Set 12 | vestmannaeyjar
# Processing Record 47 of Set 12 | kieta
# Processing Record 48 of Set 12 | kumluca
# Processing Record 49 of Set 12 | sisimiut
# Processing Record 50 of Set 12 | barddhaman
# Processing Record 1 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 2 of Set 13 | flin flon
# Processing Record 3 of Set 13 | akureyri
# Processing Record 4 of Set 13 | rongcheng
# Processing Record 5 of Set 13 | huarmey
# Processing Record 6 of Set 13 | lompoc
# Processing Record 7 of Set 13 | hammerfest
# Processing Record 8 of Set 13 | olot
# Processing Record 9 of Set 13 | kalianget
# Processing Record 10 of Set 13 | angoche
# Processing Record 11 of Set 13 | emporia
# Processing Record 12 of Set 13 | botshabelo
# Processing Record 13 of Set 13 | pechory
# Processing Record 14 of Set 13 | carutapera
# Processing Record 15 of Set 13 | statesboro
# Processing Record 16 of Set 13 | lebanon
# Processing Record 17 of Set 13 | sao raimundo nonato
# Processing Record 18 of Set 13 | isaka
# Processing Record 19 of Set 13 | tarko-sale
# Processing Record 20 of Set 13 | groa
# Processing Record 21 of Set 13 | williamsburg
# Processing Record 22 of Set 13 | makokou
# Processing Record 23 of Set 13 | aracati
# Processing Record 24 of Set 13 | jacareacanga
# Processing Record 25 of Set 13 | yuzhno-sukhokumsk
# Processing Record 26 of Set 13 | fort nelson
# Processing Record 27 of Set 13 | pangody
# Processing Record 28 of Set 13 | chilca
# Processing Record 29 of Set 13 | sao gabriel da cachoeira
# Processing Record 30 of Set 13 | vyazma
# Processing Record 31 of Set 13 | sanming
# Processing Record 32 of Set 13 | myitkyina
# Processing Record 33 of Set 13 | bucerias
# Processing Record 34 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 35 of Set 13 | ambon
# Processing Record 36 of Set 13 | panama city
# Processing Record 37 of Set 13 | saint-joseph
# Processing Record 38 of Set 13 | vallenar
# Processing Record 39 of Set 13 | bardiyah
# Processing Record 40 of Set 13 | makakilo city
# Processing Record 41 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 42 of Set 13 | la plata
# Processing Record 43 of Set 13 | basco
# Processing Record 44 of Set 13 | morros
# Processing Record 45 of Set 13 | marshfield
# Processing Record 46 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 13 | pravia
# Processing Record 48 of Set 13 | kalispell
# Processing Record 49 of Set 13 | saint-pierre
# Processing Record 50 of Set 13 | khovu-aksy
# Processing Record 1 of Set 14 | hanna
# Processing Record 2 of Set 14 | chabahar
# Processing Record 3 of Set 14 | baykit
# Processing Record 4 of Set 14 | fort frances
# Processing Record 5 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 6 of Set 14 | tiznit
# Processing Record 7 of Set 14 | porbandar
# Processing Record 8 of Set 14 | acari
# Processing Record 9 of Set 14 | manjeri
# Processing Record 10 of Set 14 | rocha
# Processing Record 11 of Set 14 | kimbe
# Processing Record 12 of Set 14 | rundu
# Processing Record 13 of Set 14 | micheweni
# Processing Record 14 of Set 14 | ingham
# Processing Record 15 of Set 14 | buchanan
# Processing Record 16 of Set 14 | plyussa
# Processing Record 17 of Set 14 | yar-sale
# Processing Record 18 of Set 14 | dhone
# Processing Record 19 of Set 14 | sistranda
# Processing Record 20 of Set 14 | les herbiers
# Processing Record 21 of Set 14 | malatya
# Processing Record 22 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 23 of Set 14 | traverse city
# Processing Record 24 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 14 | burns lake
# Processing Record 26 of Set 14 | teguise
# Processing Record 27 of Set 14 | bu salim
# City not found. Skipping...
# Processing Record 28 of Set 14 | bilma
# Processing Record 29 of Set 14 | yenagoa
# Processing Record 30 of Set 14 | buguda
# Processing Record 31 of Set 14 | cervo
# Processing Record 32 of Set 14 | santa maria del oro
# Processing Record 33 of Set 14 | were ilu
# Processing Record 34 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 35 of Set 14 | tiarei
# Processing Record 36 of Set 14 | cayenne
# Processing Record 37 of Set 14 | lorengau
# Processing Record 38 of Set 14 | southbridge
# Processing Record 39 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 14 | ljungby
# Processing Record 41 of Set 14 | terrace
# Processing Record 42 of Set 14 | trapani
# Processing Record 43 of Set 14 | caledon
# Processing Record 44 of Set 14 | nago
# Processing Record 45 of Set 14 | kapuskasing
# Processing Record 46 of Set 14 | sorland
# Processing Record 47 of Set 14 | sao miguel do araguaia
# Processing Record 48 of Set 14 | la ronge
# Processing Record 49 of Set 14 | kharp
# Processing Record 50 of Set 14 | aykhal
# Processing Record 1 of Set 15 | mandali
# Processing Record 2 of Set 15 | morant bay
# Processing Record 3 of Set 15 | oum hadjer
# Processing Record 4 of Set 15 | miles city
# Processing Record 5 of Set 15 | benha
# City not found. Skipping...
# Processing Record 6 of Set 15 | sorong
# Processing Record 7 of Set 15 | susuman
# Processing Record 8 of Set 15 | tyssedal
# Processing Record 9 of Set 15 | sabang
# Processing Record 10 of Set 15 | litovko
# Processing Record 11 of Set 15 | novopokrovka
# Processing Record 12 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 13 of Set 15 | dunedin
# Processing Record 14 of Set 15 | margate
# Processing Record 15 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 15 | lazo
# Processing Record 17 of Set 15 | aktash
# Processing Record 18 of Set 15 | rafai
# Processing Record 19 of Set 15 | baiquan
# Processing Record 20 of Set 15 | turbat
# Processing Record 21 of Set 15 | praya
# Processing Record 22 of Set 15 | konotop
# Processing Record 23 of Set 15 | ust-ishim
# Processing Record 24 of Set 15 | fujin
# Processing Record 25 of Set 15 | manokwari
# Processing Record 26 of Set 15 | gondanglegi
# Processing Record 27 of Set 15 | palmer
# Processing Record 28 of Set 15 | savinka
# Processing Record 29 of Set 15 | erdaojiang
# Processing Record 30 of Set 15 | coihaique
# Processing Record 31 of Set 15 | ust-tsilma
# Processing Record 32 of Set 15 | mosquera
# Processing Record 33 of Set 15 | cap-aux-meules
# Processing Record 34 of Set 15 | ipixuna
# Processing Record 35 of Set 15 | fierze
# City not found. Skipping...
# Processing Record 36 of Set 15 | oussouye
# Processing Record 37 of Set 15 | rabo de peixe
# Processing Record 38 of Set 15 | fuyu
# Processing Record 39 of Set 15 | ulan-ude
# Processing Record 40 of Set 15 | muromtsevo
# Processing Record 41 of Set 15 | gorontalo
# Processing Record 42 of Set 15 | araouane
# Processing Record 43 of Set 15 | jaru
# Processing Record 44 of Set 15 | poum
# Processing Record 45 of Set 15 | coahuayana
# Processing Record 46 of Set 15 | marawi
# Processing Record 47 of Set 15 | staunton
# Processing Record 48 of Set 15 | pingzhuang
# Processing Record 49 of Set 15 | krasnoufimsk
# Processing Record 50 of Set 15 | islamkot
# Processing Record 1 of Set 16 | we
# City not found. Skipping...
# Processing Record 2 of Set 16 | stepnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Talnakh      RU  69.4865   88.3972      1.20        96          99
# 1           Deder      ET   9.3167   41.4500     55.56        10           2
# 2       Upernavik      GL  72.7868  -56.1549     -3.08       100          93
# 3            Faya      SA  18.3851   42.4509     57.31        87          32
# 4           Vaini      TO -21.2000 -175.2000     75.36       100         100
# 5         Chapais      CA  49.7834  -74.8492     -4.22        92          97
# 6         Rikitea      PF -23.1203 -134.9692     78.44        71          12
# 7  Saint-Augustin      CA  51.2260  -58.6502     -0.81        84         100
# 8  Severo-Kurilsk      RU  50.6789  156.1250     28.98        94         100
# 9          Dikson      RU  73.5069   80.5464     -4.45        95         100
#
#    Wind Speed Current Description
# 0        6.58     overcast clouds
# 1        5.53           clear sky
# 2        9.84     overcast clouds
# 3        6.67    scattered clouds
# 4       13.80          light rain
# 5        3.49     overcast clouds
# 6        7.72          light rain
# 7        7.16     overcast clouds
# 8        6.17          light snow
# 9        6.35     overcast clouds

# %%
len(city_data_df)
# Out:
# 691

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691 entries, 0 to 690
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 691 non-null    object
#  1   Country              691 non-null    object
#  2   Lat                  691 non-null    float64
#  3   Lng                  691 non-null    float64
#  4   Max Temp             691 non-null    float64
#  5   Humidity             691 non-null    int64
#  6   Cloudiness           691 non-null    int64
#  7   Wind Speed           691 non-null    float64
#  8   Current Description  691 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 48.7+ KB
